# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Exercise 1
X = np.random.normal(0,4,size=(10000))
Norm_p = pd.DataFrame(X)

# %%
#Exercise 2
plt.hist(X,histtype='step')  # arguments are passed to np.histogram
plt.title("Histogram")
plt.show()

# %%
#Exercise 3
Cum_Mean = Norm_p.expanding().mean()

# %%
#Exercise 4
Cum_std_err = Norm_p.rolling(len(Norm_p),min_periods=2).std()

# %%
# Exercise 5 Bare mean and std deviation?
Norm_P_mean = np.mean(Norm_p)
Norm_P_median = np.median(Norm_p)

# However, our distribution mean = 0,
# Out:
# C:\Users\Sebastian\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
#Exercise 6
x_vals = list(range(1,len(Cum_Mean)+1))

plt.plot(x_vals,Cum_Mean,'-')

# %%
plt.errorbar(np.array(x_vals),np.array(Cum_Mean),yerr = list(Cum_std_err))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 plt.errorbar(np.array(x_vals),np.array(Cum_Mean),yerr = list(Cum_std_err))
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\pyplot.py:2492, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2486 @_copy_docstring_and_deprecators(Axes.errorbar)
#    2487 def errorbar(
#    2488         x, y, yerr=None, xerr=None, fmt='', ecolor=None,
#    2489         elinewidth=None, capsize=None, barsabove=False, lolims=False,
#    2490         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2491         capthick=None, *, data=None, **kwargs):
# -> 2492     return gca().errorbar(
#    2493         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2494         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#    2495         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2496         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
#    2497         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:3601, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3595     raise ValueError(
#    3596         f"'{dep_axis}err' must not contain negative values")
#    3597 # This is like
#    3598 #     elow, ehigh = np.broadcast_to(...)
#    3599 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3600 # except that broadcast_to would strip units.
# -> 3601 low, high = dep + np.row_stack([-(1 - lolims), 1 - uplims]) * err
#    3603 barcols.append(lines_func(
#    3604     *apply_mask([indep, low, high], everymask), **eb_lines_style))
#    3605 # Normal errorbars for points without upper/lower limits.
#
# ValueError: operands could not be broadcast together with shapes (10000,1) (2,10000)

# %%
list(Cum_std_err)
# Out:
# [0]

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=Cum_std_err[0:len(x)], label='both limits (default)')


plt.legend(loc='lower right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 6
#       3 y = 2.5 * np.sin(x / 20 * np.pi)
#       4 yerr = np.linspace(0.05, 0.2, 10)
# ----> 6 plt.errorbar(x, y + 3, yerr=Cum_std_err[0:len(x)], label='both limits (default)')
#       9 plt.legend(loc='lower right')
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\pyplot.py:2492, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2486 @_copy_docstring_and_deprecators(Axes.errorbar)
#    2487 def errorbar(
#    2488         x, y, yerr=None, xerr=None, fmt='', ecolor=None,
#    2489         elinewidth=None, capsize=None, barsabove=False, lolims=False,
#    2490         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2491         capthick=None, *, data=None, **kwargs):
# -> 2492     return gca().errorbar(
#    2493         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2494         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#    2495         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2496         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
#    2497         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Sebastian\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:3588, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3586     np.broadcast_to(err, (2, len(dep)))
#    3587 except ValueError:
# -> 3588     raise ValueError(
#    3589         f"'{dep_axis}err' (shape: {np.shape(err)}) must be a "
#    3590         f"scalar or a 1D or (2, n) array-like whose shape matches "
#    3591         f"'{dep_axis}' (shape: {np.shape(dep)})") from None
#    3592 res = np.zeros(err.shape, dtype=bool)  # Default in case of nan
#    3593 if np.any(np.less(err, -err, out=res, where=(err == err))):
#    3594     # like err<0, but also works for timedelta and nan.
#
# ValueError: 'yerr' (shape: (10, 1)) must be a scalar or a 1D or (2, n) array-like whose shape matches 'y' (shape: (10,))

# %%
#Exercise 7
