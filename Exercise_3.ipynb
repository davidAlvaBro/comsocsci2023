# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.normal(0,4,size=(1,10000))

# %%
plt.hist(np.random.normal(0,4,size=(1,100)), bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()
